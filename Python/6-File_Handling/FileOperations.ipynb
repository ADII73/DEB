# %%
# This is for file processing

with open('example.txt','r') as file:
    content=file.read()
    print(content)

with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Aditya will become Air Force officer
# He is very good
# I will become PARA SF officer
# Definately one day
# Aditya will become Air Force officer
# He is very good
# I will become PARA SF officer
# Definately one day

# %%
with open ('example.txt','w') as file:
    file.write("Aditya will become Air Force officer\n")
    file.write("He is very good")

with open("example.txt",'r') as file:
    content=file.read()
    print(content)

print()

with open ('example.txt','a') as file:
    file.write("\nI will become PARA SF officer\n")
    file.write("Definately one day")

    
with open("example.txt",'r') as file:
    content=file.read()
    print(content)
# Out:
# Aditya will become Air Force officer
# He is very good
#
# Aditya will become Air Force officer
# He is very good
# I will become PARA SF officer
# Definately one day
