# %%
import os
new_directory="packagesss"
os.mkdir(new_directory)
print(f"The new directory '{new_directory}' created")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 new_directory="packagesss"
# ----> 3 os.mkdir(new_directory)
#       4 print(f"The new directory '{new_directory}' created")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'packagesss'

# %%
items=os.listdir()
print(items)
# Out:
# ['example.txt', 'FileOperations.ipynb', 'FilePaths.ipynb', 'package', 'packagesss']

# %%
import os
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\Aditya Routh\OneDrive - Tuteck Technologies Private Limited\Desktop\DataEngineeringBootcamp\Python\6-File_Handling\folder\file.txt
