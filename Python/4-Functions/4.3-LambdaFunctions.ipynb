# %%
# A small anonymous function without a name, can have any number or arguments but only one operation/expression

# Variable = lambda parameters:operation (since it is function without name hence need to call it to a variable)

addition= lambda a,b :a+b
print(addition(2,5))
# Out:
# 7

# %%
even = lambda num:num%2==0
print(even(245))
# Out:
# False
