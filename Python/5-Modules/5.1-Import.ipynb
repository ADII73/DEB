# %%
import math # When want to use function from math library
print(math.sqrt(16))
print((math.pi))


from math import pi,sqrt # When want to use specific function from math library
print(pi)
# Out:
# 4.0
# 3.141592653589793
# 3.141592653589793

# %%
import numpy as np  # Giving alias of library for ease
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from math import * # It will import all function from library then just need to call it accordingly
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from Packages.maths import add as addition # From packages folder take math file and import add function from it    
from Packages import maths # Another way of calling modules
print(maths.add(2,32))
print(addition(2,3))
# Out:
# 34
# 5
