# %%
try :   # In try block possible chance of exception will put
    a=b

except:  # In except that exception will be handled
    print("this is an exception")
# Out:
# this is an exception

# %%
try:

    num=1/0

except ZeroDivisionError as ex:
    print(ex)
    print("Number cannot be divided by zero")
# Out:
# division by zero
# Number cannot be divided by zero

# %%
try:     # Multiple try statement - if one statement got its exceptt then try will not execute next steps 
    print("2")
    num2=1/0
    print("1")
    num=1/2
    print("3")
    a=c

except ZeroDivisionError as ex:
    print(ex)
    print("Number cannot be divided by zero")
# Out:
# 2
# division by zero
# Number cannot be divided by zero

# %%
try:  # For mutilple try exception we will have to multiple try except statements 
    print("1")
    num2=1/0
    
    print("3")
    a=c

except:
    print("Issue")

try:
    print("2")
    d=n
except:
    print("issue 2")
# Out:
# 1
# Issue
# 2
# issue 2

# %%
try:
    a=b
except Exception as ex1:
    print(ex1)

try:
    result=1/0
except Exception as ex1:
    print(ex1)
# Out:
# name 'b' is not defined
# division by zero

# %%
try :     # Two excepts or more can cover all the scenarios for a single try statement
    num=int(input("Enter number"))
    result = 10/num

except Exception as ex1: 
    print(ex1)
except Exception as ex2:
    print(ex2)

else:  #  When want to show output when no exception is occured
    print(f"The result is  {result}")

finally:
    print("Execution completed")
# Out:
# The result is  0.19607843137254902
# Execution completed

# %%
# File handling and exception handling

try:
    file=open('example.txt','r+')
    file.write("Good")
    file.seek(0)   # Move cursor to the beginning
    content=file.read()
    print(content)
except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("File closed")
# Out:
# Good
# File closed
